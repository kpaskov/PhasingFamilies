# %%
import numpy as np

# %% [markdown]
# # First, create GWAS bed file

# %%
sites = set()
with open('../data/gwas_catalog_v1.0-associations_e98_r2020-02-08.tsv', 'r') as f:
    next(f) # skip header
    for line in f:
        pieces = line.strip().split('\t')
        if pieces[12] == '' or 'x' in pieces[12]:
            pass
        elif ';' in pieces[12]:
            sites.update([(pieces[11], int(pos)) for pos in pieces[12].split(';')])
        else:
            sites.add((pieces[11], int(pieces[12])))
print('Sites', len(sites))
# Out:
# Sites 111564

# %%
sites = sorted(sites)
with open('../data/gwas_catalog_sites.bed', 'w+') as f:
    for site in sites:
        f.write('chr%s:%d-%d\n' % (site[0], site[1]-1, site[1]))

# %% [markdown]
# # Now, quantify overlaps

# %%
chroms = [str(x) for x in range(1, 23)]

def fraction_of_sites(data_dir, ref_version):
    overlapping_sites = 0
    total_sites = 0
    for chrom in chroms:
        print(chrom)

        # pull gwas sites
        sites = set()
        with open('../data/gwas_catalog_sites%s.bed' % ref_version, 'r') as f:
            for line in f:
                pieces = line.strip().split(':')
                if pieces[0][3:] == chrom:
                    sites.add(int(pieces[1].split('-')[1]))
        sites = sorted(sites)

        # pull snp positions
        pos_data = np.load('%s/chr.%s.gen.coordinates.npy' % (data_dir, chrom))
        is_snp = pos_data[:, 2].astype(bool)
        is_pass = pos_data[:, 3].astype(bool)
        #is_pass = np.ones(is_snp.shape, dtype=bool)
        snp_positions = pos_data[:, 1]
        print('Sites pulled from vcf:', snp_positions.shape[0])

        snp_positions = snp_positions[is_snp & is_pass]
        print('Removed %d sites that are not bi-allelic SNPs' % np.sum(~is_snp))
        print('Removed %d sites that do not pass GATK' % np.sum(is_snp & ~is_pass))

        print('Final matrix', snp_positions.shape)

        overlapping_sites += np.sum(np.isin(sites, snp_positions))
        total_sites += len(sites)

    return overlapping_sites/total_sites

# %%
data_dir = '../split_gen_ihart'
ref_version = '37'

ihart_p = fraction_of_sites('../split_gen_ihart', '37')
spark_exome_p = fraction_of_sites('../split_gen_spark_exome', '38')
spark_p = fraction_of_sites('../split_gen_spark', '38')
# Out:
# 1
# Sites pulled from vcf: 6256374
# Removed 521542 sites that are not bi-allelic SNPs
# Removed 277807 sites that do not pass GATK
# Final matrix (5457025,)
# 2
# Sites pulled from vcf: 6686571
# Removed 555889 sites that are not bi-allelic SNPs
# Removed 175037 sites that do not pass GATK
# Final matrix (5955645,)
# 3
# Sites pulled from vcf: 5454928
# Removed 450460 sites that are not bi-allelic SNPs
# Removed 68971 sites that do not pass GATK
# Final matrix (4935497,)
# 4
# Sites pulled from vcf: 5513425
# Removed 455548 sites that are not bi-allelic SNPs
# Removed 122178 sites that do not pass GATK
# Final matrix (4935699,)
# 5
# Sites pulled from vcf: 5017956
# Removed 412536 sites that are not bi-allelic SNPs
# Removed 83225 sites that do not pass GATK
# Final matrix (4522195,)
# 6
# Sites pulled from vcf: 4737122
# Removed 405438 sites that are not bi-allelic SNPs
# Removed 57838 sites that do not pass GATK
# Final matrix (4273846,)
# 7
# Sites pulled from vcf: 4575691
# Removed 385370 sites that are not bi-allelic SNPs
# Removed 153013 sites that do not pass GATK
# Final matrix (4037308,)
# 8
# Sites pulled from vcf: 4325765
# Removed 333069 sites that are not bi-allelic SNPs
# Removed 109504 sites that do not pass GATK
# Final matrix (3883192,)
# 9
# Sites pulled from vcf: 3590864
# Removed 285428 sites that are not bi-allelic SNPs
# Removed 285358 sites that do not pass GATK
# Final matrix (3020078,)
# 10
# Sites pulled from vcf: 3776526
# Removed 312637 sites that are not bi-allelic SNPs
# Removed 103676 sites that do not pass GATK
# Final matrix (3360213,)
# 11
# Sites pulled from vcf: 3778798
# Removed 305481 sites that are not bi-allelic SNPs
# Removed 61717 sites that do not pass GATK
# Final matrix (3411600,)
# 12
# Sites pulled from vcf: 3628877
# Removed 311858 sites that are not bi-allelic SNPs
# Removed 47635 sites that do not pass GATK
# Final matrix (3269384,)
# 13
# Sites pulled from vcf: 2709335
# Removed 234111 sites that are not bi-allelic SNPs
# Removed 31206 sites that do not pass GATK
# Final matrix (2444018,)
# 14
# Sites pulled from vcf: 2557992
# Removed 213814 sites that are not bi-allelic SNPs
# Removed 74145 sites that do not pass GATK
# Final matrix (2270033,)
# 15
# Sites pulled from vcf: 2363512
# Removed 199190 sites that are not bi-allelic SNPs
# Removed 127120 sites that do not pass GATK
# Final matrix (2037202,)
# 16
# Sites pulled from vcf: 2618350
# Removed 197743 sites that are not bi-allelic SNPs
# Removed 136111 sites that do not pass GATK
# Final matrix (2284496,)
# 17
# Sites pulled from vcf: 2218018
# Removed 194643 sites that are not bi-allelic SNPs
# Removed 65280 sites that do not pass GATK
# Final matrix (1958095,)
# 18
# Sites pulled from vcf: 2130996
# Removed 179402 sites that are not bi-allelic SNPs
# Removed 30655 sites that do not pass GATK
# Final matrix (1920939,)
# 19
# Sites pulled from vcf: 1785995
# Removed 160648 sites that are not bi-allelic SNPs
# Removed 45322 sites that do not pass GATK
# Final matrix (1580025,)
# 20
# Sites pulled from vcf: 1707845
# Removed 140243 sites that are not bi-allelic SNPs
# Removed 36098 sites that do not pass GATK
# Final matrix (1531504,)
# 21
# Sites pulled from vcf: 1153632
# Removed 98085 sites that are not bi-allelic SNPs
# Removed 114060 sites that do not pass GATK
# Final matrix (941487,)
# 22
# Sites pulled from vcf: 1096535
# Removed 91886 sites that are not bi-allelic SNPs
# Removed 70557 sites that do not pass GATK
# Final matrix (934092,)
# 1
# Sites pulled from vcf: 642809
# Removed 62981 sites that are not bi-allelic SNPs
# Removed 972 sites that do not pass GATK
# Final matrix (578856,)
# 2
# Sites pulled from vcf: 468851
# Removed 46816 sites that are not bi-allelic SNPs
# Removed 662 sites that do not pass GATK
# Final matrix (421373,)
# 3
# Sites pulled from vcf: 369138
# Removed 37097 sites that are not bi-allelic SNPs
# Removed 659 sites that do not pass GATK
# Final matrix (331382,)
# 4
# Sites pulled from vcf: 258184
# Removed 26795 sites that are not bi-allelic SNPs
# Removed 353 sites that do not pass GATK
# Final matrix (231036,)
# 5
# Sites pulled from vcf: 282308
# Removed 28633 sites that are not bi-allelic SNPs
# Removed 341 sites that do not pass GATK
# Final matrix (253334,)
# 6
# Sites pulled from vcf: 315815
# Removed 32186 sites that are not bi-allelic SNPs
# Removed 714 sites that do not pass GATK
# Final matrix (282915,)
# 7
# Sites pulled from vcf: 312633
# Removed 31359 sites that are not bi-allelic SNPs
# Removed 564 sites that do not pass GATK
# Final matrix (280710,)
# 8
# Sites pulled from vcf: 233674
# Removed 23594 sites that are not bi-allelic SNPs
# Removed 293 sites that do not pass GATK
# Final matrix (209787,)
# 9
# Sites pulled from vcf: 282802
# Removed 27663 sites that are not bi-allelic SNPs
# Removed 522 sites that do not pass GATK
# Final matrix (254617,)
# 10
# Sites pulled from vcf: 266851
# Removed 26804 sites that are not bi-allelic SNPs
# Removed 380 sites that do not pass GATK
# Final matrix (239667,)
# 11
# Sites pulled from vcf: 377032
# Removed 36168 sites that are not bi-allelic SNPs
# Removed 555 sites that do not pass GATK
# Final matrix (340309,)
# 12
# Sites pulled from vcf: 340760
# Removed 34110 sites that are not bi-allelic SNPs
# Removed 583 sites that do not pass GATK
# Final matrix (306067,)
# 13
# Sites pulled from vcf: 112239
# Removed 11627 sites that are not bi-allelic SNPs
# Removed 141 sites that do not pass GATK
# Final matrix (100471,)
# 14
# Sites pulled from vcf: 199642
# Removed 20491 sites that are not bi-allelic SNPs
# Removed 266 sites that do not pass GATK
# Final matrix (178885,)
# 15
# Sites pulled from vcf: 222231
# Removed 22190 sites that are not bi-allelic SNPs
# Removed 384 sites that do not pass GATK
# Final matrix (199657,)
# 16
# Sites pulled from vcf: 317294
# Removed 31396 sites that are not bi-allelic SNPs
# Removed 620 sites that do not pass GATK
# Final matrix (285278,)
# 17
# Sites pulled from vcf: 378025
# Removed 37330 sites that are not bi-allelic SNPs
# Removed 603 sites that do not pass GATK
# Final matrix (340092,)
# 18
# Sites pulled from vcf: 101625
# Removed 10664 sites that are not bi-allelic SNPs
# Removed 139 sites that do not pass GATK
# Final matrix (90822,)
# 19
# Sites pulled from vcf: 437424
# Removed 43917 sites that are not bi-allelic SNPs
# Removed 1086 sites that do not pass GATK
# Final matrix (392421,)
# 20
# Sites pulled from vcf: 165373
# Removed 15983 sites that are not bi-allelic SNPs
# Removed 262 sites that do not pass GATK
# Final matrix (149128,)
# 21
# Sites pulled from vcf: 73688
# Removed 7519 sites that are not bi-allelic SNPs
# Removed 148 sites that do not pass GATK
# Final matrix (66021,)
# 22
# Sites pulled from vcf: 151826
# Removed 14798 sites that are not bi-allelic SNPs
# Removed 303 sites that do not pass GATK
# Final matrix (136725,)
# 1
# Sites pulled from vcf: 49076
# Removed 455 sites that are not bi-allelic SNPs
# Removed 1207 sites that do not pass GATK
# Final matrix (47414,)
# 2
# Sites pulled from vcf: 51804
# Removed 789 sites that are not bi-allelic SNPs
# Removed 1959 sites that do not pass GATK
# Final matrix (49056,)
# 3
# Sites pulled from vcf: 43164
# Removed 485 sites that are not bi-allelic SNPs
# Removed 1881 sites that do not pass GATK
# Final matrix (40798,)
# 4
# Sites pulled from vcf: 39709
# Removed 248 sites that are not bi-allelic SNPs
# Removed 2393 sites that do not pass GATK
# Final matrix (37068,)
# 5
# Sites pulled from vcf: 37315
# Removed 434 sites that are not bi-allelic SNPs
# Removed 1574 sites that do not pass GATK
# Final matrix (35307,)
# 6
# Sites pulled from vcf: 43997
# Removed 308 sites that are not bi-allelic SNPs
# Removed 1502 sites that do not pass GATK
# Final matrix (42187,)
# 7
# Sites pulled from vcf: 34698
# Removed 334 sites that are not bi-allelic SNPs
# Removed 976 sites that do not pass GATK
# Final matrix (33388,)
# 8
# Sites pulled from vcf: 31841
# Removed 204 sites that are not bi-allelic SNPs
# Removed 764 sites that do not pass GATK
# Final matrix (30873,)
# 9
# Sites pulled from vcf: 26521
# Removed 237 sites that are not bi-allelic SNPs
# Removed 687 sites that do not pass GATK
# Final matrix (25597,)
# 10
# Sites pulled from vcf: 30509
# Removed 224 sites that are not bi-allelic SNPs
# Removed 686 sites that do not pass GATK
# Final matrix (29599,)
# 11
# Sites pulled from vcf: 31023
# Removed 439 sites that are not bi-allelic SNPs
# Removed 692 sites that do not pass GATK
# Final matrix (29892,)
# 12
# Sites pulled from vcf: 29582
# Removed 267 sites that are not bi-allelic SNPs
# Removed 761 sites that do not pass GATK
# Final matrix (28554,)
# 13
# Sites pulled from vcf: 21829
# Removed 340 sites that are not bi-allelic SNPs
# Removed 848 sites that do not pass GATK
# Final matrix (20641,)
# 14
# Sites pulled from vcf: 19879
# Removed 145 sites that are not bi-allelic SNPs
# Removed 520 sites that do not pass GATK
# Final matrix (19214,)
# 15
# Sites pulled from vcf: 18845
# Removed 227 sites that are not bi-allelic SNPs
# Removed 480 sites that do not pass GATK
# Final matrix (18138,)
# 16
# Sites pulled from vcf: 20428
# Removed 238 sites that are not bi-allelic SNPs
# Removed 367 sites that do not pass GATK
# Final matrix (19823,)
# 17
# Sites pulled from vcf: 18949
# Removed 397 sites that are not bi-allelic SNPs
# Removed 332 sites that do not pass GATK
# Final matrix (18220,)
# 18
# Sites pulled from vcf: 17820
# Removed 100 sites that are not bi-allelic SNPs
# Removed 723 sites that do not pass GATK
# Final matrix (16997,)
# 19
# Sites pulled from vcf: 14202
# Removed 157 sites that are not bi-allelic SNPs
# Removed 228 sites that do not pass GATK
# Final matrix (13817,)
# 20
# Sites pulled from vcf: 14888
# Removed 93 sites that are not bi-allelic SNPs
# Removed 292 sites that do not pass GATK
# Final matrix (14503,)
# 21
# Sites pulled from vcf: 8654
# Removed 61 sites that are not bi-allelic SNPs
# Removed 399 sites that do not pass GATK
# Final matrix (8194,)
# 22
# Sites pulled from vcf: 8967
# Removed 91 sites that are not bi-allelic SNPs
# Removed 130 sites that do not pass GATK
# Final matrix (8746,)

# %%
ihart_chip_p = fraction_of_sites('../split_gen_ihart_chip', '37')
ssc_p = fraction_of_sites('../split_gen_ssc', '37')
# Out:
# 1
# Sites pulled from vcf: 49067
# Removed 9414 sites that are not bi-allelic SNPs
# Removed 137 sites that do not pass GATK
# Final matrix (39516,)
# 2
# Sites pulled from vcf: 41971
# Removed 6716 sites that are not bi-allelic SNPs
# Removed 111 sites that do not pass GATK
# Final matrix (35144,)
# 3
# Sites pulled from vcf: 35363
# Removed 5912 sites that are not bi-allelic SNPs
# Removed 104 sites that do not pass GATK
# Final matrix (29347,)
# 4
# Sites pulled from vcf: 29203
# Removed 4092 sites that are not bi-allelic SNPs
# Removed 92 sites that do not pass GATK
# Final matrix (25019,)
# 5
# Sites pulled from vcf: 29463
# Removed 4528 sites that are not bi-allelic SNPs
# Removed 97 sites that do not pass GATK
# Final matrix (24838,)
# 6
# Sites pulled from vcf: 34243
# Removed 5039 sites that are not bi-allelic SNPs
# Removed 136 sites that do not pass GATK
# Final matrix (29068,)
# 7
# Sites pulled from vcf: 27498
# Removed 4299 sites that are not bi-allelic SNPs
# Removed 112 sites that do not pass GATK
# Final matrix (23087,)
# 8
# Sites pulled from vcf: 24333
# Removed 3391 sites that are not bi-allelic SNPs
# Removed 59 sites that do not pass GATK
# Final matrix (20883,)
# 9
# Sites pulled from vcf: 23018
# Removed 3606 sites that are not bi-allelic SNPs
# Removed 64 sites that do not pass GATK
# Final matrix (19348,)
# 10
# Sites pulled from vcf: 24506
# Removed 3674 sites that are not bi-allelic SNPs
# Removed 80 sites that do not pass GATK
# Final matrix (20752,)
# 11
# Sites pulled from vcf: 30499
# Removed 5968 sites that are not bi-allelic SNPs
# Removed 119 sites that do not pass GATK
# Final matrix (24412,)
# 12
# Sites pulled from vcf: 27029
# Removed 4851 sites that are not bi-allelic SNPs
# Removed 93 sites that do not pass GATK
# Final matrix (22085,)
# 13
# Sites pulled from vcf: 15275
# Removed 1711 sites that are not bi-allelic SNPs
# Removed 52 sites that do not pass GATK
# Final matrix (13512,)
# 14
# Sites pulled from vcf: 17392
# Removed 3000 sites that are not bi-allelic SNPs
# Removed 57 sites that do not pass GATK
# Final matrix (14335,)
# 15
# Sites pulled from vcf: 17225
# Removed 3184 sites that are not bi-allelic SNPs
# Removed 52 sites that do not pass GATK
# Final matrix (13989,)
# 16
# Sites pulled from vcf: 19642
# Removed 3719 sites that are not bi-allelic SNPs
# Removed 40 sites that do not pass GATK
# Final matrix (15883,)
# 17
# Sites pulled from vcf: 21606
# Removed 4892 sites that are not bi-allelic SNPs
# Removed 69 sites that do not pass GATK
# Final matrix (16645,)
# 18
# Sites pulled from vcf: 12232
# Removed 1479 sites that are not bi-allelic SNPs
# Removed 45 sites that do not pass GATK
# Final matrix (10708,)
# 19
# Sites pulled from vcf: 21976
# Removed 5546 sites that are not bi-allelic SNPs
# Removed 128 sites that do not pass GATK
# Final matrix (16302,)
# 20
# Sites pulled from vcf: 13574
# Removed 2345 sites that are not bi-allelic SNPs
# Removed 30 sites that do not pass GATK
# Final matrix (11199,)
# 21
# Sites pulled from vcf: 7027
# Removed 1023 sites that are not bi-allelic SNPs
# Removed 27 sites that do not pass GATK
# Final matrix (5977,)
# 22
# Sites pulled from vcf: 9271
# Removed 1776 sites that are not bi-allelic SNPs
# Removed 26 sites that do not pass GATK
# Final matrix (7469,)
# 1
# Sites pulled from vcf: 4322811
# Removed 389659 sites that are not bi-allelic SNPs
# Removed 193203 sites that do not pass GATK
# Final matrix (3739949,)
# 2
# Sites pulled from vcf: 4546447
# Removed 409662 sites that are not bi-allelic SNPs
# Removed 123103 sites that do not pass GATK
# Final matrix (4013682,)
# 3
# Sites pulled from vcf: 3712955
# Removed 331654 sites that are not bi-allelic SNPs
# Removed 55992 sites that do not pass GATK
# Final matrix (3325309,)
# 4
# Sites pulled from vcf: 3705866
# Removed 332943 sites that are not bi-allelic SNPs
# Removed 93990 sites that do not pass GATK
# Final matrix (3278933,)
# 5
# Sites pulled from vcf: 3393824
# Removed 302837 sites that are not bi-allelic SNPs
# Removed 61841 sites that do not pass GATK
# Final matrix (3029146,)
# 6
# Sites pulled from vcf: 3259209
# Removed 301726 sites that are not bi-allelic SNPs
# Removed 53364 sites that do not pass GATK
# Final matrix (2904119,)
# 7
# Sites pulled from vcf: 3159698
# Removed 287737 sites that are not bi-allelic SNPs
# Removed 113989 sites that do not pass GATK
# Final matrix (2757972,)
# 8
# Sites pulled from vcf: 2947949
# Removed 246237 sites that are not bi-allelic SNPs
# Removed 77075 sites that do not pass GATK
# Final matrix (2624637,)
# 9
# Sites pulled from vcf: 2494973
# Removed 214040 sites that are not bi-allelic SNPs
# Removed 200424 sites that do not pass GATK
# Final matrix (2080509,)
# 10
# Sites pulled from vcf: 2596797
# Removed 234225 sites that are not bi-allelic SNPs
# Removed 80498 sites that do not pass GATK
# Final matrix (2282074,)
# 11
# Sites pulled from vcf: 2605588
# Removed 228245 sites that are not bi-allelic SNPs
# Removed 49016 sites that do not pass GATK
# Final matrix (2328327,)
# 12
# Sites pulled from vcf: 2490595
# Removed 232209 sites that are not bi-allelic SNPs
# Removed 40167 sites that do not pass GATK
# Final matrix (2218219,)
# 13
# Sites pulled from vcf: 1833519
# Removed 172315 sites that are not bi-allelic SNPs
# Removed 24909 sites that do not pass GATK
# Final matrix (1636295,)
# 14
# Sites pulled from vcf: 1745655
# Removed 158794 sites that are not bi-allelic SNPs
# Removed 51715 sites that do not pass GATK
# Final matrix (1535146,)
# 15
# Sites pulled from vcf: 1630771
# Removed 148550 sites that are not bi-allelic SNPs
# Removed 84493 sites that do not pass GATK
# Final matrix (1397728,)
# 16
# Sites pulled from vcf: 1826038
# Removed 151131 sites that are not bi-allelic SNPs
# Removed 97192 sites that do not pass GATK
# Final matrix (1577715,)
# 17
# Sites pulled from vcf: 1554495
# Removed 148698 sites that are not bi-allelic SNPs
# Removed 50234 sites that do not pass GATK
# Final matrix (1355563,)
# 18
# Sites pulled from vcf: 1452466
# Removed 132674 sites that are not bi-allelic SNPs
# Removed 25402 sites that do not pass GATK
# Final matrix (1294390,)
# 19
# Sites pulled from vcf: 1274408
# Removed 126200 sites that are not bi-allelic SNPs
# Removed 39483 sites that do not pass GATK
# Final matrix (1108725,)
# 20
# Sites pulled from vcf: 1188112
# Removed 106379 sites that are not bi-allelic SNPs
# Removed 31677 sites that do not pass GATK
# Final matrix (1050056,)
# 21
# Sites pulled from vcf: 814347
# Removed 74790 sites that are not bi-allelic SNPs
# Removed 83278 sites that do not pass GATK
# Final matrix (656279,)
# 22
# Sites pulled from vcf: 772603
# Removed 70924 sites that are not bi-allelic SNPs
# Removed 47806 sites that do not pass GATK
# Final matrix (653873,)

# %%
print(ihart_p, spark_exome_p, spark_p)
# Out:
# 0.9190769319971782 0.05058414598822053 0.15546007531138362

# %%
print(ihart_chip_p, ssc_p)
# Out:
# 0.14385249466085562 0.9262376668180632
