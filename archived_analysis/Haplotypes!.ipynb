# %%
from scipy.sparse import load_npz
import matplotlib.pyplot as plt
import numpy as np
import sklearn.cluster
from collections import defaultdict, namedtuple, Counter
from os import listdir
from itertools import combinations
import json
import scipy.stats as stats

# %%
phase_dir = '../phased_spark_quads_del'
with open('%s/chr.10.125500000.126500000.families.json' % phase_dir, 'r') as f:
    families = json.load(f)
ped_file = '../../DATA/spark/spark.ped.quads.ped'
identicals_file = '../sibpair_similarity/spark_quads_identicals.txt'
    
parental_variants = load_npz('%s/chr.10.125500000.126500000.parental_variants.npz' % phase_dir)

# %%
has_variant = parental_variants.T.dot(np.ones((parental_variants.shape[0],)))>0
has_variant_indices = has_variant.nonzero()[0] 
var_data = parental_variants[:, has_variant].A
print(var_data.shape)
# Out:
# (632, 260)

# %%
families_to_remove = sorted(set([int(np.floor(x/4)) for x in np.where(np.all(var_data==0, axis=1))[0]]))
families = [x for i, x in enumerate(families) if i not in families_to_remove]
indices = np.ones((parental_variants.shape[0],), dtype=bool)
for i in families_to_remove:
    indices[(4*i):(4*(i+1))] = False
var_data = var_data[indices, :]
print(len(families)*4)
print(var_data.shape)
# Out:
# 632
# (632, 260)

# %%
plt.figure(figsize=(15, 25))
plt.imshow(var_data, aspect='auto', vmin=0, vmax=1)
plt.show()

# %%
plt.hist(var_data.flatten()[var_data.flatten() != 0], bins=np.arange(0, 1.01, 0.01))
plt.show()

# %%
print(np.min(var_data), np.max(var_data))
# Out:
# 0.0 0.999999999999949

# %%
#clustering = sklearn.cluster.AgglomerativeClustering(affinity='cosine', linkage='complete',
#                                                     n_clusters=2).fit(var_data)

clustering = sklearn.cluster.DBSCAN(metric='cosine', eps=0.6, min_samples=5).fit((var_data>0.9).astype(int))

# %%
print(Counter(clustering.labels_))
# Out:
# Counter({0: 630, -1: 2})

# %%
num_clusters = np.max(clustering.labels_)+1
cluster_centroids = np.zeros((num_clusters, var_data.shape[1]))
for i in range(num_clusters):
    cluster_centroids[i, :] = np.mean(var_data[clustering.labels_==i, :], axis=0)
    plt.hist(cluster_centroids[i, :], bins=np.arange(0, 1.01, 0.01), alpha=0.5, log=True)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.imshow(cluster_centroids, aspect='auto', vmin=0, vmax=1)
plt.show()

# %% [markdown]
# # Now do haplotype TDT

# %%
chrom = '10'
start_interval, end_interval = 125500000, 126500000

# %%
def pull_phenotype_ped(ped_file):
	sample_to_sex = dict()
	sample_to_affected = dict()
	with open(ped_file, 'r') as f:
		for line in f:
			pieces = line.strip().split('\t')
			sample_to_sex[pieces[1]] = pieces[4]
			sample_to_affected[pieces[1]] = pieces[5]
	return sample_to_affected, sample_to_sex

sample_to_affected, sample_to_sex = pull_phenotype_ped(ped_file)

# %%
# pull identicals
leave_out = set()
with open(identicals_file, 'r') as f:
	for line in f:
		pieces = line.strip().split('\t')
		leave_out.update(pieces[1:])

# %%
# pull transmission matrix
# cluster, notrans/trans, unaff/aff, mat/pat
transmission = np.zeros((num_clusters, 2, 2, 2))
for family_index, family in enumerate(families):
    # figure out which cluster the parental haplotypes are in
    haplotypes = clustering.labels_[(4*family_index):(4*(family_index+1))]
    
    # figure out which parental copy is transmitted
    # child1/child2, 0/1/2/3
    trans_data = np.zeros((2, 4), dtype=int)
    print('%s/%s.phased.txt' % (phase_dir, family))
    with open('%s/%s.phased.txt' % (phase_dir, family), 'r')  as f:
        try:
            header = next(f).strip().split('\t')
            individuals = [header[i][:-4] for i in range(5, len(header)-3, 2)]

            if len(individuals)==4:
                for line in f:
                    pieces = line.strip().split('\t')
                    if pieces[0][3:] == chrom:
                        start_pos, end_pos = [int(x) for x in pieces[-2:]]
                        state = np.array([int(x) for x in pieces[1:-2]])

                        sib1_ind_index, sib2_ind_index = 2, 3
                        sib1_mat_index, sib2_mat_index = 4+2*sib1_ind_index, 4+2*sib2_ind_index
                        sib1_pat_index, sib2_pat_index = 5+2*sib1_ind_index, 5+2*sib2_ind_index

                        overlap = min(end_interval, end_pos) - max(start_interval, start_pos)
                        if overlap > 0:
                            if state[sib1_mat_index] != -1:
                                trans_data[0, int(state[sib1_mat_index])] += overlap
                            if state[sib1_pat_index] != -1:
                                trans_data[0, int(state[sib1_pat_index])] += overlap
                            if state[sib2_mat_index] != -1:
                                trans_data[1, int(state[sib2_mat_index])] += overlap
                            if state[sib2_pat_index] != -1:
                                trans_data[1, int(state[sib2_pat_index])] += overlap

                assert np.all(np.sum(trans_data[:, :2], axis=1) <= (end_interval-start_interval))
                assert np.all(np.sum(trans_data[:, 2:], axis=1) <= (end_interval-start_interval))

                # figure out child phenotypes
                aff = [int(sample_to_affected[x]=='2') for x in individuals[2:4]]

                opp_anc_index = {0:1, 1:0, 2:3, 3:2}

                # cluster, notrans/trans, unaff/aff
                for child_index in range(2):
                    if individuals[2+child_index] not in leave_out:
                        for anc_index in range(4):
                            if trans_data[child_index, anc_index] >= 0.9*(end_interval-start_interval):
                                transmission[haplotypes[anc_index], 1, aff[child_index], int(anc_index<2)] += 1
                                transmission[haplotypes[opp_anc_index[anc_index]], 0, aff[child_index], int(anc_index<2)] += 1

                        leave_out.add(individuals[2+child_index])
        except:
            pass
# Out:
# ../phased_spark_quads_del/SF0000027.SP0000027.SP0000034.phased.txt
# ../phased_spark_quads_del/SF0000027.SP0000027.SP0000063.phased.txt
# ../phased_spark_quads_del/SF0000027.SP0000034.SP0000063.phased.txt
# ../phased_spark_quads_del/SF0000145.SP0001673.SP0000145.phased.txt
# ../phased_spark_quads_del/SF0000226.SP0000285.SP0000226.phased.txt
# ../phased_spark_quads_del/SF0000267.SP0001200.SP0000267.phased.txt
# ../phased_spark_quads_del/SF0000300.SP0000447.SP0000300.phased.txt
# ../phased_spark_quads_del/SF0000300.SP0000447.SP0000734.phased.txt
# ../phased_spark_quads_del/SF0000300.SP0000734.SP0000300.phased.txt
# ../phased_spark_quads_del/SF0000301.SP0000301.SP0000760.phased.txt
# ../phased_spark_quads_del/SF0000362.SP0000523.SP0000362.phased.txt
# ../phased_spark_quads_del/SF0000463.SP0000463.SP0000533.phased.txt
# ../phased_spark_quads_del/SF0000551.SP0001640.SP0000551.phased.txt
# ../phased_spark_quads_del/SF0000834.SP0000834.SP0001066.phased.txt
# ../phased_spark_quads_del/SF0000834.SP0000967.SP0000834.phased.txt
# ../phased_spark_quads_del/SF0000834.SP0000967.SP0001066.phased.txt
# ../phased_spark_quads_del/SF0000834.SP0000967.SP0001099.phased.txt
# ../phased_spark_quads_del/SF0000834.SP0001099.SP0001066.phased.txt
# ../phased_spark_quads_del/SF0000938.SP0000938.SP0000996.phased.txt
# ../phased_spark_quads_del/SF0000974.SP0000974.SP0001012.phased.txt
# ../phased_spark_quads_del/SF0001493.SP0001546.SP0001493.phased.txt
# ../phased_spark_quads_del/SF0001506.SP0001506.SP0001527.phased.txt
# ../phased_spark_quads_del/SF0001583.SP0001583.SP0001619.phased.txt
# ../phased_spark_quads_del/SF0001591.SP0001591.SP0001626.phased.txt
# ../phased_spark_quads_del/SF0001660.SP0001660.SP0001692.phased.txt
# ../phased_spark_quads_del/SF0001752.SP0002136.SP0001752.phased.txt
# ../phased_spark_quads_del/SF0001753.SP0006937.SP0001753.phased.txt
# ../phased_spark_quads_del/SF0001948.SP0001983.SP0001948.phased.txt
# ../phased_spark_quads_del/SF0001953.SP0001986.SP0001953.phased.txt
# ../phased_spark_quads_del/SF0002124.SP0002124.SP0002157.phased.txt
# ../phased_spark_quads_del/SF0002252.SP0002252.SP0002281.phased.txt
# ../phased_spark_quads_del/SF0002517.SP0002517.SP0002547.phased.txt
# ../phased_spark_quads_del/SF0002519.SP0002552.SP0002519.phased.txt
# ../phased_spark_quads_del/SF0002542.SP0002655.SP0002542.phased.txt
# ../phased_spark_quads_del/SF0002634.SP0002634.SP0002667.phased.txt
# ../phased_spark_quads_del/SF0002676.SP0002676.SP0002706.phased.txt
# ../phased_spark_quads_del/SF0003127.SP0003156.SP0003127.phased.txt
# ../phased_spark_quads_del/SF0003127.SP0003185.SP0003127.phased.txt
# ../phased_spark_quads_del/SF0003127.SP0003185.SP0003156.phased.txt
# ../phased_spark_quads_del/SF0003134.SP0004092.SP0003134.phased.txt
# ../phased_spark_quads_del/SF0003176.SP0003220.SP0003176.phased.txt
# ../phased_spark_quads_del/SF0003205.SP0003239.SP0003205.phased.txt
# ../phased_spark_quads_del/SF0003502.SP0003519.SP0003502.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003687.SP0003695.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003691.SP0003687.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003691.SP0003692.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003691.SP0003695.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003692.SP0003687.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003692.SP0003695.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003694.SP0003687.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003694.SP0003691.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003694.SP0003692.phased.txt
# ../phased_spark_quads_del/SF0003691.SP0003694.SP0003695.phased.txt
# ../phased_spark_quads_del/SF0003744.SP0003743.SP0003744.phased.txt
# ../phased_spark_quads_del/SF0003831.SP0003832.SP0003831.phased.txt
# ../phased_spark_quads_del/SF0003929.SP0003929.SP0004013.phased.txt
# ../phased_spark_quads_del/SF0003944.SP0003976.SP0003944.phased.txt
# ../phased_spark_quads_del/SF0003952.SP0004087.SP0003952.phased.txt
# ../phased_spark_quads_del/SF0003960.SP0003960.SP0003300.phased.txt
# ../phased_spark_quads_del/SF0003997.SP0004150.SP0003997.phased.txt
# ../phased_spark_quads_del/SF0004000.SP0004000.SP0004081.phased.txt
# ../phased_spark_quads_del/SF0004009.SP0004009.SP0004112.phased.txt
# ../phased_spark_quads_del/SF0004051.SP0004051.SP0004392.phased.txt
# ../phased_spark_quads_del/SF0004093.SP0006356.SP0004093.phased.txt
# ../phased_spark_quads_del/SF0004144.SP0006025.SP0004144.phased.txt
# ../phased_spark_quads_del/SF0004157.SP0004157.SP0004270.phased.txt
# ../phased_spark_quads_del/SF0004219.SP0004219.SP0004311.phased.txt
# ../phased_spark_quads_del/SF0004234.SP0004234.SP0004371.phased.txt
# ../phased_spark_quads_del/SF0004244.SP0004244.SP0004380.phased.txt
# ../phased_spark_quads_del/SF0004319.SP0004319.SP0004354.phased.txt
# ../phased_spark_quads_del/SF0004387.SP0005075.SP0004387.phased.txt
# ../phased_spark_quads_del/SF0004396.SP0004430.SP0004396.phased.txt
# ../phased_spark_quads_del/SF0004472.SP0004472.SP0004587.phased.txt
# ../phased_spark_quads_del/SF0004507.SP0004742.SP0004507.phased.txt
# ../phased_spark_quads_del/SF0004521.SP0004521.SP0004794.phased.txt
# ../phased_spark_quads_del/SF0004650.SP0004650.SP0004889.phased.txt
# ../phased_spark_quads_del/SF0004726.SP0004726.SP0004825.phased.txt
# ../phased_spark_quads_del/SF0004727.SP0003918.SP0004727.phased.txt
# ../phased_spark_quads_del/SF0004790.SP0004790.SP0004842.phased.txt
# ../phased_spark_quads_del/SF0004790.SP0004790.SP0004967.phased.txt
# ../phased_spark_quads_del/SF0004790.SP0005101.SP0004790.phased.txt
# ../phased_spark_quads_del/SF0004790.SP0005101.SP0004842.phased.txt
# ../phased_spark_quads_del/SF0004790.SP0005101.SP0004967.phased.txt
# ../phased_spark_quads_del/SF0005064.SP0005129.SP0005064.phased.txt
# ../phased_spark_quads_del/SF0005068.SP0005068.SP0005132.phased.txt
# ../phased_spark_quads_del/SF0005093.SP0005093.SP0005229.phased.txt
# ../phased_spark_quads_del/SF0005165.SP0005165.SP0023436.phased.txt
# ../phased_spark_quads_del/SF0005182.SP0005182.SP0005215.phased.txt
# ../phased_spark_quads_del/SF0005184.SP0005184.SP0122946.phased.txt
# ../phased_spark_quads_del/SF0005195.SP0005195.SP0020408.phased.txt
# ../phased_spark_quads_del/SF0005275.SP0005275.SP0005307.phased.txt
# ../phased_spark_quads_del/SF0005277.SP0005344.SP0005277.phased.txt
# ../phased_spark_quads_del/SF0005299.SP0005401.SP0005299.phased.txt
# ../phased_spark_quads_del/SF0005315.SP0005315.SP0005483.phased.txt
# ../phased_spark_quads_del/SF0005327.SP0005327.SP0004477.phased.txt
# ../phased_spark_quads_del/SF0005356.SP0005455.SP0005356.phased.txt
# ../phased_spark_quads_del/SF0005363.SP0005619.SP0005363.phased.txt
# ../phased_spark_quads_del/SF0005375.SP0005375.SP0005541.phased.txt
# ../phased_spark_quads_del/SF0005392.SP0005392.SP0005456.phased.txt
# ../phased_spark_quads_del/SF0005413.SP0005481.SP0005413.phased.txt
# ../phased_spark_quads_del/SF0005443.SP0005513.SP0005443.phased.txt
# ../phased_spark_quads_del/SF0005462.SP0005635.SP0005462.phased.txt
# ../phased_spark_quads_del/SF0005499.SP0005702.SP0005499.phased.txt
# ../phased_spark_quads_del/SF0005505.SP0005534.SP0005505.phased.txt
# ../phased_spark_quads_del/SF0005594.SP0005629.SP0005594.phased.txt
# ../phased_spark_quads_del/SF0005632.SP0005755.SP0005632.phased.txt
# ../phased_spark_quads_del/SF0005657.SP0005657.SP0005828.phased.txt
# ../phased_spark_quads_del/SF0005657.SP0005657.SP0005896.phased.txt
# ../phased_spark_quads_del/SF0005657.SP0005828.SP0005896.phased.txt
# ../phased_spark_quads_del/SF0005675.SP0005675.SP0005848.phased.txt
# ../phased_spark_quads_del/SF0005675.SP0005675.SP0006047.phased.txt
# ../phased_spark_quads_del/SF0005675.SP0006047.SP0005848.phased.txt
# ../phased_spark_quads_del/SF0005776.SP0005776.SP0005884.phased.txt
# ../phased_spark_quads_del/SF0005799.SP0006003.SP0005799.phased.txt
# ../phased_spark_quads_del/SF0005811.SP0005811.SP0005847.phased.txt
# ../phased_spark_quads_del/SF0005862.SP0005862.SP0006036.phased.txt
# ../phased_spark_quads_del/SF0005890.SP0005890.SP0005950.phased.txt
# ../phased_spark_quads_del/SF0005898.SP0005898.SP0005968.phased.txt
# ../phased_spark_quads_del/SF0005898.SP0005898.SP0006169.phased.txt
# ../phased_spark_quads_del/SF0005898.SP0005968.SP0006169.phased.txt
# ../phased_spark_quads_del/SF0005978.SP0006105.SP0005978.phased.txt
# ../phased_spark_quads_del/SF0005989.SP0006353.SP0005989.phased.txt
# ../phased_spark_quads_del/SF0006028.SP0006276.SP0006028.phased.txt
# ../phased_spark_quads_del/SF0006106.SP0006106.SP0006171.phased.txt
# ../phased_spark_quads_del/SF0006155.SP0006155.SP0006188.phased.txt
# ../phased_spark_quads_del/SF0006225.SP0006225.SP0006292.phased.txt
# ../phased_spark_quads_del/SF0006284.SP0006284.SP0006348.phased.txt
# ../phased_spark_quads_del/SF0006284.SP0006387.SP0006284.phased.txt
# ../phased_spark_quads_del/SF0006284.SP0006387.SP0006348.phased.txt
# ../phased_spark_quads_del/SF0006290.SP0006290.SP0006463.phased.txt
# ../phased_spark_quads_del/SF0006321.SP0006321.SP0006392.phased.txt
# ../phased_spark_quads_del/SF0006428.SP0006428.SP0006476.phased.txt
# ../phased_spark_quads_del/SF0006503.SP0006503.SP0006573.phased.txt
# ../phased_spark_quads_del/SF0006503.SP0006503.SP0006639.phased.txt
# ../phased_spark_quads_del/SF0006503.SP0006639.SP0006573.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0006709.SP0006640.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0006709.SP0006743.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0006709.SP0007080.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0006743.SP0006640.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0006743.SP0007080.phased.txt
# ../phased_spark_quads_del/SF0006640.SP0007080.SP0006640.phased.txt
# ../phased_spark_quads_del/SF0006718.SP0006718.SP0006748.phased.txt
# ../phased_spark_quads_del/SF0006741.SP0006741.SP0006848.phased.txt
# ../phased_spark_quads_del/SF0006750.SP0006820.SP0006750.phased.txt
# ../phased_spark_quads_del/SF0006821.SP0006821.SP0007008.phased.txt
# ../phased_spark_quads_del/SF0006872.SP0006872.SP0007036.phased.txt
# ../phased_spark_quads_del/SF0006954.SP0006954.SP0007057.phased.txt
# ../phased_spark_quads_del/SF0006987.SP0006987.SP0007158.phased.txt
# ../phased_spark_quads_del/SF0007194.SP0007194.SP0007300.phased.txt
# ../phased_spark_quads_del/SF0007216.SP0007216.SP0007392.phased.txt
# ../phased_spark_quads_del/SF0007307.SP0007307.SP0007379.phased.txt
# ../phased_spark_quads_del/SF0007336.SP0007336.SP0007435.phased.txt
# ../phased_spark_quads_del/SF0007354.SP0007354.SP0004378.phased.txt
# ../phased_spark_quads_del/SF0007383.SP0007383.SP0007520.phased.txt
# ../phased_spark_quads_del/SF0007400.SP0007668.SP0007400.phased.txt
# ../phased_spark_quads_del/SF0007459.SP0007561.SP0007459.phased.txt
# ../phased_spark_quads_del/SF0007514.SP0007514.SP0007651.phased.txt
# ../phased_spark_quads_del/SF0007581.SP0007581.SP0007713.phased.txt

# %%
for i in range(num_clusters):
    try:
        print(i, 'n=', np.sum(clustering.labels_==i))
        #print('maternal')
        #print(transmission[i, :, :, 0])
        #print('unaff', stats.binom_test(transmission[i, :, 0, 0]))
        #print('aff', stats.binom_test(transmission[i, :, 1, 0]))
        #print('chi2', stats.chi2_contingency(transmission[i, :, :, 0])[1])
        #print('paternal')
        #print(transmission[i, :, :, 1])
        #print('unaff', stats.binom_test(transmission[i, :, 0, 1]))
        #print('aff', stats.binom_test(transmission[i, :, 1, 1]))
        #print('chi2', stats.chi2_contingency(transmission[i, :, :, 1])[1])
        #print('both')
        print(np.sum(transmission[i, :, :, :], axis=2))
        print('unaff', stats.binom_test(np.sum(transmission[i, :, 0, :], axis=1)))
        print('aff', stats.binom_test(np.sum(transmission[i, :, 1, :], axis=1)))
        print('chi2', stats.chi2_contingency(np.sum(transmission[i, :, :, :], axis=2))[1])
        print()
    except:
        pass
# Out:
# 0 n= 630
# [[205. 286.]
#  [205. 286.]]
# unaff 1.0
# aff 1.0
# chi2 1.0
